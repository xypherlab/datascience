# %% [markdown]
# # Retention Study - Figuring Out Which Employees May Quit
# ### Loading our Main HR Database Records

# %%
import pandas as pd

# Uncomment this line if using this notebook locally
#hr_df = pd.read_csv('./data/employee_retention/hr_data.csv') 

file_name = "https://raw.githubusercontent.com/rajeevratan84/datascienceforbusiness/master/hr_data.csv"
hr_df = pd.read_csv(file_name)

# We use the dataframe name followed by a '.head()' to use the head function to 
# preview the first 5 records of the dataframe. If you wanted to preview the first 10, simply 
# put dataframe_name.head(10)
hr_df.head()
# Out:
#    employee_id  number_project  ...  department  salary
# 0         1003               2  ...       sales     low
# 1         1005               5  ...       sales  medium
# 2         1486               7  ...       sales  medium
# 3         1038               5  ...       sales     low
# 4         1057               2  ...       sales     low
#
# [5 rows x 9 columns]

# %%
# View the bottom 5 rows
hr_df.tail()
# Out:
#        employee_id  number_project  ...  department  salary
# 14994        87670               2  ...     support     low
# 14995        87673               2  ...     support     low
# 14996        87679               2  ...     support     low
# 14997        87681               6  ...     support     low
# 14998        87684               2  ...     support     low
#
# [5 rows x 9 columns]

# %%
hr_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 9 columns):
# employee_id              14999 non-null int64
# number_project           14999 non-null int64
# average_montly_hours     14999 non-null int64
# time_spend_company       14999 non-null int64
# Work_accident            14999 non-null int64
# left                     14999 non-null int64
# promotion_last_5years    14999 non-null int64
# department               14999 non-null object
# salary                   14999 non-null object
# dtypes: int64(7), object(2)
# memory usage: 1.0+ MB

# %%
# View which columns are categorical
hr_df.select_dtypes(exclude=['int', 'float']).columns
# Out:
# Index(['department', 'salary'], dtype='object')

# %%
# Display values in categorical columns
print(hr_df['department'].unique())
print(hr_df['salary'].unique())
# Out:
# ['sales' 'accounting' 'hr' 'technical' 'support' 'management' 'IT'
#  'product_mng' 'marketing' 'RandD']
# ['low' 'medium' 'high']

# %%
# How many rows are in our dataset?
len(hr_df)
# Out:
# 14999

# %%
# What about how many columns?
len(hr_df.columns)
# Out:
# 9

# %%
hr_df.shape
# Out:
# (14999, 9)

# %% [markdown]
# ### Loading our Evaluation and Employee Satisfaction Data

# %%
# Uncomment this line if using this notebook locally
#emp_satis_eval = pd.read_excel ('./data/employee_retention/employee_satisfaction_evaluation.xlsx') 

file_name = "https://raw.githubusercontent.com/rajeevratan84/datascienceforbusiness/master/employee_satisfaction_evaluation.xlsx"
emp_satis_eval = pd.read_excel(file_name)

emp_satis_eval.head()
# Out:
#    EMPLOYEE #  satisfaction_level  last_evaluation
# 0        1003                0.38             0.53
# 1        1005                0.80             0.86
# 2        1486                0.11             0.88
# 3        1038                0.72             0.87
# 4        1057                0.37             0.52

# %%
emp_satis_eval.shape
# Out:
# (14999, 3)

# %% [markdown]
# ### Merge or Join Tables

# %%
main_df = hr_df.set_index('employee_id').join(emp_satis_eval.set_index('EMPLOYEE #'))
main_df = main_df.reset_index()
main_df.head()
# Out:
#    employee_id  number_project  ...  satisfaction_level  last_evaluation
# 0         1003               2  ...                0.38             0.53
# 1         1005               5  ...                0.80             0.86
# 2         1486               7  ...                0.11             0.88
# 3         1038               5  ...                0.72             0.87
# 4         1057               2  ...                0.37             0.52
#
# [5 rows x 11 columns]

# %% [markdown]
# ### Is our dataset good? Are there missing values?

# %%
#main_df.isnull()
main_df[main_df.isnull().any(axis=1)]
# Out:
#        employee_id  number_project  ...  satisfaction_level  last_evaluation
# 18            3794               2  ...                 NaN              NaN
# 19            1140               5  ...                 NaN             0.89
# 33            1230               2  ...                 NaN              NaN
# 53            1340               2  ...                 NaN              NaN
# 72           22316               2  ...                 NaN              NaN
# 92            1581               2  ...                 NaN              NaN
# 107          17376               2  ...                 NaN              NaN
# 120           1739               4  ...                 NaN              NaN
# 137           1847               2  ...                 NaN              NaN
# 175          32923               4  ...                 NaN              NaN
# 191           2160               4  ...                0.92              NaN
# 352           3150               4  ...                 NaN             0.91
# 376           3250               4  ...                0.56              NaN
# 402           3405               5  ...                 NaN             1.00
# 427          78130               3  ...                 NaN             0.60
# 442           3635               5  ...                0.77              NaN
# 468           3755               5  ...                 NaN             0.92
# 543           4150               5  ...                0.89              NaN
# 892          43615               4  ...                0.74              NaN
# 1588         42185               5  ...                 NaN             0.81
# 1934         11895               4  ...                0.78              NaN
# 2343         14170               3  ...                 NaN             0.97
# 2743         16445               5  ...                0.62              NaN
# 3170         18980               5  ...                 NaN              NaN
# 3609         21580               3  ...                0.95              NaN
# 3776         22555               4  ...                 NaN             0.68
# 4122         24505               3  ...                0.86              NaN
# 4740         27950               3  ...                 NaN             0.95
# 5028         29640               4  ...                0.64              NaN
# 6453         38090               5  ...                 NaN             0.78
# 7005         41535               4  ...                0.82              NaN
# 7516         44460               4  ...                 NaN             0.97
# 8630         50960               4  ...                0.90              NaN
# 9455         55770               4  ...                 NaN             0.88
# 9901         58630               5  ...                0.92              NaN
# 10647        62595               4  ...                 NaN             0.69
# 10962        64350               5  ...                0.65              NaN
# 11575        20215               3  ...                 NaN              NaN
# 11967        70005               3  ...                0.82              NaN
# 12422        72475               5  ...                 NaN             1.00
# 12853        74880               3  ...                 NaN             0.70
# 13482        78780               3  ...                0.58              NaN
# 13925        81315               3  ...                 NaN             0.75
#
# [43 rows x 11 columns]

# %% [markdown]
# ### Let's fill in the missing blanks with the aveage values

# %%
main_df.describe()
# Out:
#         employee_id  number_project  ...  satisfaction_level  last_evaluation
# count  14999.000000    14999.000000  ...        14972.000000     14972.000000
# mean   45424.627575        3.803054  ...            0.612830         0.716125
# std    25915.900127        1.232592  ...            0.248714         0.171138
# min     1003.000000        2.000000  ...            0.090000         0.360000
# 25%    22872.500000        3.000000  ...            0.440000         0.560000
# 50%    45448.000000        4.000000  ...            0.640000         0.720000
# 75%    67480.500000        5.000000  ...            0.820000         0.870000
# max    99815.000000        7.000000  ...            1.000000         1.000000
#
# [8 rows x 9 columns]

# %%
main_df.fillna(main_df.mean(), inplace=True)
main_df.head()
# Out:
#    employee_id  number_project  ...  satisfaction_level  last_evaluation
# 0         1003               2  ...                0.38             0.53
# 1         1005               5  ...                0.80             0.86
# 2         1486               7  ...                0.11             0.88
# 3         1038               5  ...                0.72             0.87
# 4         1057               2  ...                0.37             0.52
#
# [5 rows x 11 columns]

# %%
#main_df[main_df.employee_id == 3794]
main_df.loc[main_df['employee_id'] == 3794]
# Out:
#     employee_id  number_project  ...  satisfaction_level  last_evaluation
# 18         3794               2  ...             0.61283         0.716125
#
# [1 rows x 11 columns]

# %%
main_df.head()
# Out:
#    employee_id  number_project  ...  satisfaction_level  last_evaluation
# 0         1003               2  ...                0.38             0.53
# 1         1005               5  ...                0.80             0.86
# 2         1486               7  ...                0.11             0.88
# 3         1038               5  ...                0.72             0.87
# 4         1057               2  ...                0.37             0.52
#
# [5 rows x 11 columns]

# %%
# Removing employee ID
main_df_final = main_df.drop(columns='employee_id')
main_df_final.head()
# Out:
#    number_project  average_montly_hours  ...  satisfaction_level  last_evaluation
# 0               2                   157  ...                0.38             0.53
# 1               5                   262  ...                0.80             0.86
# 2               7                   272  ...                0.11             0.88
# 3               5                   223  ...                0.72             0.87
# 4               2                   159  ...                0.37             0.52
#
# [5 rows x 10 columns]

# %%
main_df_final.groupby('department').sum()
# Out:
#              number_project  ...  last_evaluation
# department                   ...
# IT                     4683  ...       879.452250
# RandD                  3033  ...       560.446125
# accounting             2934  ...       550.706125
# hr                     2701  ...       524.006125
# management             2432  ...       456.234499
# marketing              3164  ...       613.946125
# product_mng            3434  ...       644.662250
# sales                 15634  ...      2938.236749
# support                8479  ...      1611.534499
# technical             10548  ...      1961.930624
#
# [10 rows x 8 columns]

# %%
main_df_final.groupby('department').mean()
# Out:
#              number_project  ...  last_evaluation
# department                   ...
# IT                 3.816626  ...         0.716750
# RandD              3.853875  ...         0.712130
# accounting         3.825293  ...         0.718000
# hr                 3.654939  ...         0.709075
# management         3.860317  ...         0.724182
# marketing          3.687646  ...         0.715555
# product_mng        3.807095  ...         0.714703
# sales              3.776329  ...         0.709719
# support            3.803948  ...         0.722985
# technical          3.877941  ...         0.721298
#
# [10 rows x 8 columns]

# %%
main_df_final['department'].value_counts()
# Out:
# sales          4140
# technical      2720
# support        2229
# IT             1227
# product_mng     902
# marketing       858
# RandD           787
# accounting      767
# hr              739
# management      630
# Name: department, dtype: int64

# %%
main_df_final['left'].value_counts()
# Out:
# 0    11428
# 1     3571
# Name: left, dtype: int64

# %% [markdown]
# ### Displaying Your Correlation Matrix

# %%
import matplotlib.pyplot as plt

def plot_corr(df,size=10):
    '''Function plots a graphical correlation matrix for each pair of columns in the dataframe.

    Input:
        df: pandas DataFrame
        size: vertical and horizontal size of the plot'''

    corr = df.corr()
    fig, ax = plt.subplots(figsize=(size, size))
    ax.legend()
    cax = ax.matshow(corr)
    fig.colorbar(cax)
    plt.xticks(range(len(corr.columns)), corr.columns, rotation='vertical')
    plt.yticks(range(len(corr.columns)), corr.columns)
    
plot_corr(main_df_final)
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# ## Preparing out  Dataset for ML

# %%
# Perform One Hot Encoding on Categorical Data

categorial = ['department','salary']
main_df_final = pd.get_dummies(main_df_final, columns=categorial, drop_first=True)
main_df_final.head()
# Out:
#    number_project  average_montly_hours  ...  salary_low  salary_medium
# 0               2                   157  ...           1              0
# 1               5                   262  ...           0              1
# 2               7                   272  ...           0              1
# 3               5                   223  ...           1              0
# 4               2                   159  ...           1              0
#
# [5 rows x 19 columns]

# %%
# How many columns do we now have?

len(main_df_final.columns)
# Out:
# 19

# %%
# How many employees in the dataset have left?

len(main_df_final.loc[main_df_final['left'] == 1])
# Out:
# 3571

# %%
main_df_final.head()
# Out:
#    number_project  average_montly_hours  ...  salary_low  salary_medium
# 0               2                   157  ...           1              0
# 1               5                   262  ...           0              1
# 2               7                   272  ...           0              1
# 3               5                   223  ...           1              0
# 4               2                   159  ...           1              0
#
# [5 rows x 19 columns]

# %% [markdown]
# ## Preparing our Dataset for Machine Learning

# %%
from sklearn.model_selection import train_test_split

# We remove the label values from our training data
X = main_df_final.drop(['left'],axis=1).values

# We assigned those label values to our Y dataset
y = main_df_final['left'].values

# %%
# Split it to a 70:30 Ratio Train:Test

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %%
# Normalize the data
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
df_train = pd.DataFrame(X_train)
df_train.head()
# Out:
#          0         1         2   ...        15        16        17
# 0  0.154819  0.982176 -0.348757  ... -0.470814 -0.970989 -0.872345
# 1 -0.654261 -0.543186 -0.348757  ... -0.470814  1.029878 -0.872345
# 2  0.963898  0.359989 -0.348757  ... -0.470814 -0.970989  1.146335
# 3  0.963898 -0.904456 -0.348757  ...  2.123979 -0.970989  1.146335
# 4  0.154819  0.038860 -0.348757  ... -0.470814  1.029878 -0.872345
#
# [5 rows x 18 columns]

# %%
df_train.describe()
# Out:
#                  0             1   ...            16            17
# count  1.049900e+04  1.049900e+04  ...  1.049900e+04  1.049900e+04
# mean  -1.838387e-16 -4.360948e-17  ...  4.791756e-16 -1.867044e-16
# std    1.000048e+00  1.000048e+00  ...  1.000048e+00  1.000048e+00
# min   -1.463340e+00 -2.108689e+00  ... -9.709893e-01 -8.723453e-01
# 25%   -6.542607e-01 -9.044557e-01  ... -9.709893e-01 -8.723453e-01
# 50%    1.548186e-01 -1.280814e-03  ... -9.709893e-01 -8.723453e-01
# 75%    9.638979e-01  8.818236e-01  ...  1.029878e+00  1.146335e+00
# max    2.582056e+00  2.186410e+00  ...  1.029878e+00  1.146335e+00
#
# [8 rows x 18 columns]

# %% [markdown]
# ## Let's Train a Logistic Regression Model

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score

model = LogisticRegression(solver='lbfgs')
model.fit(X_train, y_train)

predictions = model.predict(X_test)

print("Accuracy {0:.2f}%".format(100*accuracy_score(predictions, y_test)))
print(confusion_matrix(y_test, predictions))
print(classification_report(y_test, predictions))
# Out:
# Accuracy 79.36%
# [[3186  252]
#  [ 677  385]]
#               precision    recall  f1-score   support
#
#            0       0.82      0.93      0.87      3438
#            1       0.60      0.36      0.45      1062
#
#     accuracy                           0.79      4500
#    macro avg       0.71      0.64      0.66      4500
# weighted avg       0.77      0.79      0.77      4500

# %% [markdown]
# ### Let's Try a Random Forest Classifer

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score

model = RandomForestClassifier()
model.fit(X_train, y_train)

predictions = model.predict(X_test)
score = model.score(X_test, y_test)

print("Accuracy {0:.2f}%".format(100*accuracy_score(predictions, y_test)))
print(confusion_matrix(y_test, predictions))
print(classification_report(y_test, predictions))
# Out:
# Accuracy 98.60%
# [[3429    9]
#  [  54 1008]]
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      3438
#            1       0.99      0.95      0.97      1062
#
#     accuracy                           0.99      4500
#    macro avg       0.99      0.97      0.98      4500
# weighted avg       0.99      0.99      0.99      4500
# /usr/local/lib/python3.6/dist-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)

# %%
hr_df.head()
# Out:
#    employee_id  number_project  ...  department  salary
# 0         1003               2  ...       sales     low
# 1         1005               5  ...       sales  medium
# 2         1486               7  ...       sales  medium
# 3         1038               5  ...       sales     low
# 4         1057               2  ...       sales     low
#
# [5 rows x 9 columns]

# %%
main_df_final.drop(['left'],axis=1).columns
# Out:
# Index(['number_project', 'average_montly_hours', 'time_spend_company',
#        'Work_accident', 'promotion_last_5years', 'satisfaction_level',
#        'last_evaluation', 'department_RandD', 'department_accounting',
#        'department_hr', 'department_management', 'department_marketing',
#        'department_product_mng', 'department_sales', 'department_support',
#        'department_technical', 'salary_low', 'salary_medium'],
#       dtype='object')

# %%
import pandas as pd
feature_importances = pd.DataFrame(model.feature_importances_,
                                   index = pd.DataFrame(X_train).columns,
                                    columns=['importance']).sort_values('importance',ascending=False)

feature_importances
# Out:
#     importance
# 5     0.302792
# 2     0.192968
# 0     0.187162
# 1     0.149797
# 6     0.124379
# 16    0.009758
# 3     0.008801
# 15    0.003940
# 17    0.003509
# 13    0.003446
# 14    0.002948
# 8     0.002079
# 7     0.001702
# 9     0.001562
# 11    0.001403
# 4     0.001384
# 12    0.001318
# 10    0.001053

# %% [markdown]
# ### Can Deep Learning Make a Difference?

# %%
# Use the newest version of TensorFlow 2.0
# %tensorflow_version 2.x
# Out:
# TensorFlow 2.x selected.

# %%
# If you wish to use Tensorflow 1.X run the following line and then restart runtime
# %tensorflow_version 1.x 
# You'll need to change your import statements from tensorflow.keras to keras
import tensorflow.keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

model = Sequential()

model.add(Dense(9, kernel_initializer = "uniform", activation = "relu", input_dim=18))
model.add(Dense(1, kernel_initializer = "uniform", activation = "sigmoid"))

model.compile(optimizer= "adam",loss = "binary_crossentropy",metrics = ["accuracy"])

# %%
# Display Model Summary and Show Parameters
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 9)                 171
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 10
# =================================================================
# Total params: 181
# Trainable params: 181
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Start Training Our Classifier 
batch_size = 10
epochs = 25

history = model.fit(X_train,
                    y_train,
                    batch_size = batch_size,
                    epochs = epochs,
                    verbose = 1,
                    validation_data = (X_test, y_test))

score = model.evaluate(X_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Train on 10499 samples, validate on 4500 samples
# Epoch 1/25
# 10499/10499 [==============================] - 3s 332us/sample - loss: 0.4197 - accuracy: 0.8266 - val_loss: 0.2756 - val_accuracy: 0.8958
# Epoch 2/25
# 10499/10499 [==============================] - 2s 199us/sample - loss: 0.2311 - accuracy: 0.9218 - val_loss: 0.2023 - val_accuracy: 0.9391
# Epoch 3/25
# 10499/10499 [==============================] - 2s 201us/sample - loss: 0.1872 - accuracy: 0.9418 - val_loss: 0.1806 - val_accuracy: 0.9469
# Epoch 4/25
# 10499/10499 [==============================] - 2s 199us/sample - loss: 0.1731 - accuracy: 0.9474 - val_loss: 0.1719 - val_accuracy: 0.9476
# Epoch 5/25
# 10499/10499 [==============================] - 2s 204us/sample - loss: 0.1664 - accuracy: 0.9496 - val_loss: 0.1686 - val_accuracy: 0.9496
# Epoch 6/25
# 10499/10499 [==============================] - 2s 201us/sample - loss: 0.1630 - accuracy: 0.9516 - val_loss: 0.1633 - val_accuracy: 0.9504
# Epoch 7/25
# 10499/10499 [==============================] - 2s 200us/sample - loss: 0.1602 - accuracy: 0.9515 - val_loss: 0.1629 - val_accuracy: 0.9511
# Epoch 8/25
# 10499/10499 [==============================] - 2s 195us/sample - loss: 0.1580 - accuracy: 0.9504 - val_loss: 0.1613 - val_accuracy: 0.9516
# Epoch 9/25
# 10499/10499 [==============================] - 2s 200us/sample - loss: 0.1568 - accuracy: 0.9522 - val_loss: 0.1599 - val_accuracy: 0.9518
# Epoch 10/25
# 10499/10499 [==============================] - 2s 199us/sample - loss: 0.1549 - accuracy: 0.9529 - val_loss: 0.1597 - val_accuracy: 0.9509
# Epoch 11/25
# 10499/10499 [==============================] - 2s 196us/sample - loss: 0.1544 - accuracy: 0.9522 - val_loss: 0.1585 - val_accuracy: 0.9509
# Epoch 12/25
# 10499/10499 [==============================] - 2s 200us/sample - loss: 0.1538 - accuracy: 0.9527 - val_loss: 0.1574 - val_accuracy: 0.9544
# Epoch 13/25
# 10499/10499 [==============================] - 2s 199us/sample - loss: 0.1524 - accuracy: 0.9531 - val_loss: 0.1590 - val_accuracy: 0.9544
# Epoch 14/25
# 10499/10499 [==============================] - 2s 198us/sample - loss: 0.1520 - accuracy: 0.9535 - val_loss: 0.1572 - val_accuracy: 0.9533
# Epoch 15/25
# 10499/10499 [==============================] - 2s 203us/sample - loss: 0.1513 - accuracy: 0.9544 - val_loss: 0.1560 - val_accuracy: 0.9549
# Epoch 16/25
# 10499/10499 [==============================] - 2s 198us/sample - loss: 0.1508 - accuracy: 0.9541 - val_loss: 0.1558 - val_accuracy: 0.9533
# Epoch 17/25
# 10499/10499 [==============================] - 2s 199us/sample - loss: 0.1505 - accuracy: 0.9535 - val_loss: 0.1557 - val_accuracy: 0.9547
# Epoch 18/25
# 10499/10499 [==============================] - 2s 197us/sample - loss: 0.1499 - accuracy: 0.9545 - val_loss: 0.1551 - val_accuracy: 0.9547
# Epoch 19/25
# 10499/10499 [==============================] - 2s 198us/sample - loss: 0.1494 - accuracy: 0.9545 - val_loss: 0.1542 - val_accuracy: 0.9542
# Epoch 20/25
# 10499/10499 [==============================] - 2s 199us/sample - loss: 0.1487 - accuracy: 0.9551 - val_loss: 0.1549 - val_accuracy: 0.9549
# Epoch 21/25
# 10499/10499 [==============================] - 2s 199us/sample - loss: 0.1483 - accuracy: 0.9550 - val_loss: 0.1524 - val_accuracy: 0.9547
# Epoch 22/25
# 10499/10499 [==============================] - 2s 194us/sample - loss: 0.1478 - accuracy: 0.9539 - val_loss: 0.1542 - val_accuracy: 0.9558
# Epoch 23/25
# 10499/10499 [==============================] - 2s 202us/sample - loss: 0.1474 - accuracy: 0.9560 - val_loss: 0.1532 - val_accuracy: 0.9553
# Epoch 24/25
# 10499/10499 [==============================] - 2s 199us/sample - loss: 0.1472 - accuracy: 0.9549 - val_loss: 0.1524 - val_accuracy: 0.9558
# Epoch 25/25
# 10499/10499 [==============================] - 2s 199us/sample - loss: 0.1473 - accuracy: 0.9547 - val_loss: 0.1517 - val_accuracy: 0.9562
# Test loss: 0.15171897461679246
# Test accuracy: 0.95622224

# %%
# Plotting our loss charts
import matplotlib.pyplot as plt

history_dict = history.history

loss_values = history_dict['loss']
val_loss_values = history_dict['val_loss']
epochs = range(1, len(loss_values) + 1)

line1 = plt.plot(epochs, val_loss_values, label='Validation/Test Loss')
line2 = plt.plot(epochs, loss_values, label='Training Loss')
plt.setp(line1, linewidth=2.0, marker = '+', markersize=10.0)
plt.setp(line2, linewidth=2.0, marker = '4', markersize=10.0)
plt.xlabel('Epochs') 
plt.ylabel('Loss')
plt.grid(True)
plt.legend()
plt.show()

# %%
# Plotting our accuracy charts
import matplotlib.pyplot as plt

history_dict = history.history

acc_values = history_dict['accuracy']
val_acc_values = history_dict['val_accuracy']
epochs = range(1, len(loss_values) + 1)

line1 = plt.plot(epochs, val_acc_values, label='Validation/Test Accuracy')
line2 = plt.plot(epochs, acc_values, label='Training Accuracy')
plt.setp(line1, linewidth=2.0, marker = '+', markersize=10.0)
plt.setp(line2, linewidth=2.0, marker = '4', markersize=10.0)
plt.xlabel('Epochs') 
plt.ylabel('Accuracy')
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# ## Displaying the Classification Report and Confusion Matrix

# %%
predictions = model.predict(X_test)
predictions = (predictions > 0.5)

print(confusion_matrix(y_test, predictions))
print(classification_report(y_test, predictions))
# Out:
# [[3350   88]
#  [ 109  953]]
#               precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97      3438
#            1       0.92      0.90      0.91      1062
#
#     accuracy                           0.96      4500
#    macro avg       0.94      0.94      0.94      4500
# weighted avg       0.96      0.96      0.96      4500

# %% [markdown]
# # Let's a Deeper Model

# %%
from tensorflow.keras.regularizers import l2
from tensorflow.keras.layers import Dropout

model2 = Sequential()

# Hidden Layer 1
model2.add(Dense(270, activation='relu', input_dim=18, kernel_regularizer=l2(0.01)))
model2.add(Dropout(0.3, noise_shape=None, seed=None))

# Hidden Layer 1
model2.add(Dense(180, activation='relu', input_dim=18, kernel_regularizer=l2(0.01)))
model2.add(Dropout(0.3, noise_shape=None, seed=None))

# Hidden Layer 2
model2.add(Dense(90, activation = 'relu', kernel_regularizer=l2(0.01)))
model.add(Dropout(0.3, noise_shape=None, seed=None))

model2.add(Dense(1, activation='sigmoid'))

model2.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_2 (Dense)              (None, 100)               1900
# _________________________________________________________________
# dropout (Dropout)            (None, 100)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 100)               10100
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 101
# =================================================================
# Total params: 12,101
# Trainable params: 12,101
# Non-trainable params: 0
# _________________________________________________________________

# %%
model2.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %% [markdown]
# ## Training our Deeper Model

# %%
batch_size = 10
epochs = 25

history = model2.fit(X_train,
                    y_train,
                    batch_size = batch_size,
                    epochs = epochs,
                    verbose = 1,
                    validation_data = (X_test, y_test))

score = model.evaluate(X_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Train on 10499 samples, validate on 4500 samples
# Epoch 1/25
# 10499/10499 [==============================] - 4s 344us/sample - loss: 0.5481 - accuracy: 0.8936 - val_loss: 0.2865 - val_accuracy: 0.9402
# Epoch 2/25
# 10499/10499 [==============================] - 3s 263us/sample - loss: 0.2688 - accuracy: 0.9358 - val_loss: 0.2338 - val_accuracy: 0.9487
# Epoch 3/25
# 10499/10499 [==============================] - 3s 261us/sample - loss: 0.2457 - accuracy: 0.9430 - val_loss: 0.2264 - val_accuracy: 0.9462
# Epoch 4/25
# 10499/10499 [==============================] - 3s 262us/sample - loss: 0.2362 - accuracy: 0.9414 - val_loss: 0.2160 - val_accuracy: 0.9524
# Epoch 5/25
# 10499/10499 [==============================] - 3s 262us/sample - loss: 0.2325 - accuracy: 0.9433 - val_loss: 0.2181 - val_accuracy: 0.9462
# Epoch 6/25
# 10499/10499 [==============================] - 3s 261us/sample - loss: 0.2299 - accuracy: 0.9431 - val_loss: 0.2140 - val_accuracy: 0.9493
# Epoch 7/25
# 10499/10499 [==============================] - 3s 259us/sample - loss: 0.2256 - accuracy: 0.9444 - val_loss: 0.2101 - val_accuracy: 0.9489
# Epoch 8/25
# 10499/10499 [==============================] - 3s 264us/sample - loss: 0.2257 - accuracy: 0.9461 - val_loss: 0.2109 - val_accuracy: 0.9482
# Epoch 9/25
# 10499/10499 [==============================] - 3s 267us/sample - loss: 0.2238 - accuracy: 0.9441 - val_loss: 0.2062 - val_accuracy: 0.9536
# Epoch 10/25
# 10499/10499 [==============================] - 3s 264us/sample - loss: 0.2194 - accuracy: 0.9461 - val_loss: 0.1988 - val_accuracy: 0.9504
# Epoch 11/25
# 10499/10499 [==============================] - 3s 262us/sample - loss: 0.2170 - accuracy: 0.9452 - val_loss: 0.2122 - val_accuracy: 0.9480
# Epoch 12/25
# 10499/10499 [==============================] - 3s 266us/sample - loss: 0.2173 - accuracy: 0.9466 - val_loss: 0.2046 - val_accuracy: 0.9513
# Epoch 13/25
# 10499/10499 [==============================] - 3s 261us/sample - loss: 0.2134 - accuracy: 0.9472 - val_loss: 0.1984 - val_accuracy: 0.9524
# Epoch 14/25
# 10499/10499 [==============================] - 3s 260us/sample - loss: 0.2128 - accuracy: 0.9483 - val_loss: 0.1973 - val_accuracy: 0.9538
# Epoch 15/25
# 10499/10499 [==============================] - 3s 267us/sample - loss: 0.2169 - accuracy: 0.9449 - val_loss: 0.1908 - val_accuracy: 0.9567
# Epoch 16/25
# 10499/10499 [==============================] - 3s 259us/sample - loss: 0.2116 - accuracy: 0.9441 - val_loss: 0.2207 - val_accuracy: 0.9360
# Epoch 17/25
# 10499/10499 [==============================] - 3s 263us/sample - loss: 0.2112 - accuracy: 0.9469 - val_loss: 0.1938 - val_accuracy: 0.9538
# Epoch 18/25
# 10499/10499 [==============================] - 3s 263us/sample - loss: 0.2092 - accuracy: 0.9474 - val_loss: 0.1957 - val_accuracy: 0.9500
# Epoch 19/25
# 10499/10499 [==============================] - 3s 263us/sample - loss: 0.2084 - accuracy: 0.9489 - val_loss: 0.2016 - val_accuracy: 0.9533
# Epoch 20/25
# 10499/10499 [==============================] - 3s 264us/sample - loss: 0.2084 - accuracy: 0.9502 - val_loss: 0.1880 - val_accuracy: 0.9582
# Epoch 21/25
# 10499/10499 [==============================] - 3s 257us/sample - loss: 0.2057 - accuracy: 0.9512 - val_loss: 0.1893 - val_accuracy: 0.9573
# Epoch 22/25
# 10499/10499 [==============================] - 3s 264us/sample - loss: 0.2089 - accuracy: 0.9481 - val_loss: 0.1899 - val_accuracy: 0.9560
# Epoch 23/25
# 10499/10499 [==============================] - 3s 266us/sample - loss: 0.2043 - accuracy: 0.9510 - val_loss: 0.2012 - val_accuracy: 0.9473
# Epoch 24/25
# 10499/10499 [==============================] - 3s 258us/sample - loss: 0.2041 - accuracy: 0.9496 - val_loss: 0.1800 - val_accuracy: 0.9613
# Epoch 25/25
# 10499/10499 [==============================] - 3s 260us/sample - loss: 0.2002 - accuracy: 0.9527 - val_loss: 0.1908 - val_accuracy: 0.9547
# Test loss: 0.15171840462419722
# Test accuracy: 0.95622224

# %%
predictions = model2.predict(X_test)
predictions = (predictions > 0.5)

print(confusion_matrix(y_test, predictions))
print(classification_report(y_test, predictions))
# Out:
# [[3325   90]
#  [ 116  969]]
#               precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97      3415
#            1       0.92      0.89      0.90      1085
#
#     accuracy                           0.95      4500
#    macro avg       0.94      0.93      0.94      4500
# weighted avg       0.95      0.95      0.95      4500
